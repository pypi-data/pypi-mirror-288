# %% [markdown]
# # Tests

# %%
import unittest

from fs.test import FSTestCases

from rclonefs import RcloneFS

class TestMyFS(FSTestCases, unittest.TestCase):
    
    def make_fs(self):
        return RcloneFS("dropbox:")

    def destroy_fs(self, fs):
        self.fs.close()

# %%
from makepy import makepy

# %%
makepy('tests')
# Out:
# 2024/07/06 23:44:31 tests

# %%
# !python3 -m unittest tests.py
# Out:
# ...<file.RcloneFile object at 0x7f7468e03970>
# Es.EEEEEEFEEEEEEEFEF.......EFEFFFFFF.EEEEEEEEE.FF.EEEEFEEE.FF..EsE....E....
# ======================================================================
# ERROR: test_bin_files (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1544, in test_bin_files
#     f.truncate(3)
#   File "/usr/lib/python3/dist-packages/fs/iotools.py", line 89, in truncate
#     return self._f.truncate(size)
# TypeError: RcloneFile.truncate() takes 1 positional argument but 2 were given
#
# ======================================================================
# ERROR: test_copy (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1172, in test_copy
#     self.fs.copy("foo", "bar")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 418, in copy
#     self.upload(dst_path, read_file)  # type: ignore
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 229, in upload
#     local_path = str(file.name, encoding='utf-8')
# TypeError: decoding str is not supported
#
# ======================================================================
# ERROR: test_copy_dir_mem (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1676, in test_copy_dir_mem
#     self._test_copy_dir("mem://")
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1630, in _test_copy_dir
#     self.fs.makedirs("foo/bar/baz")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz' should be a directory
#
# ======================================================================
# ERROR: test_copy_dir_temp (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1681, in test_copy_dir_temp
#     self._test_copy_dir("temp://")
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1630, in _test_copy_dir
#     self.fs.makedirs("foo/bar/baz")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz' should be a directory
#
# ======================================================================
# ERROR: test_copy_file (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1608, in test_copy_file
#     fs.copy.copy_file(self.fs, "foo.txt", self.fs, "bar.txt")
#   File "/usr/lib/python3/dist-packages/fs/copy.py", line 134, in copy_file
#     _src_fs.copy(src_path, dst_path, overwrite=True)
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 418, in copy
#     self.upload(dst_path, read_file)  # type: ignore
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 229, in upload
#     local_path = str(file.name, encoding='utf-8')
# TypeError: decoding str is not supported
#
# ======================================================================
# ERROR: test_copy_structure (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1618, in test_copy_structure
#     self.fs.makedirs("foo/bar/baz")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz' should be a directory
#
# ======================================================================
# ERROR: test_copydir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1751, in test_copydir
#     self.fs.makedirs("foo/bar/baz/egg")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz/egg' should be a directory
#
# ======================================================================
# ERROR: test_desc (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1290, in test_desc
#     self.fs.desc("")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 478, in desc
#     raise errors.ResourceNotFound(path)
# fs.errors.ResourceNotFound: resource '' not found
#
# ======================================================================
# ERROR: test_download (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1431, in test_download
#     self.fs.download("hello.bin", write_file)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 239, in download
#     local_path = file.name
# AttributeError: '_io.BytesIO' object has no attribute 'name'
#
# ======================================================================
# ERROR: test_download_0 (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1247, in test_download_0
#     self._test_download(0)
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1238, in _test_download
#     src_fs.makedir("dir1").writebytes("baz", data3)
# AttributeError: 'NoneType' object has no attribute 'writebytes'
#
# ======================================================================
# ERROR: test_download_1 (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1250, in test_download_1
#     self._test_download(1)
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1238, in _test_download
#     src_fs.makedir("dir1").writebytes("baz", data3)
# AttributeError: 'NoneType' object has no attribute 'writebytes'
#
# ======================================================================
# ERROR: test_download_2 (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1253, in test_download_2
#     self._test_download(2)
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1238, in _test_download
#     src_fs.makedir("dir1").writebytes("baz", data3)
# AttributeError: 'NoneType' object has no attribute 'writebytes'
#
# ======================================================================
# ERROR: test_download_4 (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1256, in test_download_4
#     self._test_download(4)
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1238, in _test_download
#     src_fs.makedir("dir1").writebytes("baz", data3)
# AttributeError: 'NoneType' object has no attribute 'writebytes'
#
# ======================================================================
# ERROR: test_download_chunk_size (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1441, in test_download_chunk_size
#     self.fs.download("hello.bin", write_file, chunk_size=8)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 239, in download
#     local_path = file.name
# AttributeError: '_io.BytesIO' object has no attribute 'name'
#
# ======================================================================
# ERROR: test_files (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1584, in test_files
#     f.truncate(3)
#   File "/usr/lib/python3/dist-packages/fs/iotools.py", line 89, in truncate
#     return self._f.truncate(size)
# TypeError: RcloneFile.truncate() takes 1 positional argument but 2 were given
#
# ======================================================================
# ERROR: test_hash (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:47:44 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1853, in test_hash
#     self.fs.makedir("foo").writebytes("hashme.txt", b"foobar" * 1024)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_isdir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:47:46 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 388, in test_isdir
#     self.fs.makedir("foo")
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_move (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 602, in test_move
#     self.fs.move("foo", "bar")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1103, in move
#     raise errors.DestinationExists(dst_path)
# fs.errors.DestinationExists: destination 'bar' exists
#
# ======================================================================
# ERROR: test_move_dir_mem (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1701, in test_move_dir_mem
#     self._test_move_dir_write("mem://")
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1692, in _test_move_dir_write
#     fs.move.move_dir(other_fs, "/", self.fs, "/")
#   File "/usr/lib/python3/dist-packages/fs/move.py", line 89, in move_dir
#     copy_dir(src_fs, src_path, dst_fs, dst_path, workers=workers)
#   File "/usr/lib/python3/dist-packages/fs/copy.py", line 300, in copy_dir
#     copier.copy(_src_fs, src_path, _dst_fs, dst_path)
#   File "/usr/lib/python3/dist-packages/fs/_bulk.py", line 132, in copy
#     copy_file_internal(src_fs, src_path, dst_fs, dst_path)
#   File "/usr/lib/python3/dist-packages/fs/copy.py", line 176, in copy_file_internal
#     dst_fs.upload(dst_path, read_file)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 229, in upload
#     local_path = str(file.name, encoding='utf-8')
# AttributeError: '_MemoryFile' object has no attribute 'name'
#
# ======================================================================
# ERROR: test_move_dir_temp (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1704, in test_move_dir_temp
#     self._test_move_dir_write("temp://")
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1692, in _test_move_dir_write
#     fs.move.move_dir(other_fs, "/", self.fs, "/")
#   File "/usr/lib/python3/dist-packages/fs/move.py", line 89, in move_dir
#     copy_dir(src_fs, src_path, dst_fs, dst_path, workers=workers)
#   File "/usr/lib/python3/dist-packages/fs/copy.py", line 300, in copy_dir
#     copier.copy(_src_fs, src_path, _dst_fs, dst_path)
#   File "/usr/lib/python3/dist-packages/fs/_bulk.py", line 132, in copy
#     copy_file_internal(src_fs, src_path, dst_fs, dst_path)
#   File "/usr/lib/python3/dist-packages/fs/copy.py", line 176, in copy_file_internal
#     dst_fs.upload(dst_path, read_file)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 232, in upload
#     raise ResourceNotFound(parent_dir)
# fs.errors.ResourceNotFound: resource '/foo/bar/baz' not found
#
# ======================================================================
# ERROR: test_move_file_mem (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:48:11 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1745, in test_move_file_mem
#     self._test_move_file("mem://")
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1732, in _test_move_file
#     self.fs.makedir("foo").writetext("test.txt", text)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_move_file_same_fs (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:48:12 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1721, in test_move_file_same_fs
#     self.fs.makedir("foo").writetext("test.txt", text)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_move_file_temp (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:48:12 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1748, in test_move_file_temp
#     self._test_move_file("temp://")
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1732, in _test_move_file
#     self.fs.makedir("foo").writetext("test.txt", text)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_move_same_fs (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1707, in test_move_same_fs
#     self.fs.makedirs("foo/bar/baz")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz' should be a directory
#
# ======================================================================
# ERROR: test_movedir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1768, in test_movedir
#     self.fs.makedirs("foo/bar/baz/egg")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz/egg' should be a directory
#
# ======================================================================
# ERROR: test_open (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:48:19 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 714, in test_open
#     self.fs.makedir("foo")
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_openbin_rw (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:48:28 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 770, in test_openbin_rw
#     self.fs.makedir("foo")
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_opendir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:48:29 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1008, in test_opendir
#     self.fs.makedir("foo")
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_readbytes (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/osfs.py", line 359, in openbin
#     binary_file = io.open(
# FileNotFoundError: [Errno 2] No such file or directory: b'/tmp/tmplcfvodll__tempfs__/baz'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1425, in test_readbytes
#     self.fs.readbytes("baz")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 603, in readbytes
#     with closing(self.open(path, mode="rb")) as read_file:
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1166, in open
#     bin_file = self.openbin(path, mode=bin_mode, buffering=buffering)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 224, in openbin
#     return RcloneFile(self, path, mode)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/file.py", line 28, in __init__
#     self.file = self.temp_fs.openbin(self.internal_path, mode)
#   File "/usr/lib/python3/dist-packages/fs/osfs.py", line 356, in openbin
#     with convert_os_errors("openbin", path):
#   File "/usr/lib/python3/dist-packages/fs/error_tools.py", line 90, in __exit__
#     reraise(fserror, fserror(self._path, exc=exc_value), traceback)
#   File "/usr/lib/python3/dist-packages/six.py", line 718, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/lib/python3/dist-packages/fs/osfs.py", line 359, in openbin
#     binary_file = io.open(
# fs.errors.ResourceNotFound: resource 'baz' not found
#
# ======================================================================
# ERROR: test_readtext (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 165, in makedir
#     self.rclone.mkdir(self._path(path))
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 48, in mkdir
#     self._run_command(["mkdir", path], flags)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclone.py", line 19, in _run_command
#     raise Exception(f"RClone command failed: {result.stderr}")
# Exception: RClone command failed: 2024/07/06 23:48:40 Failed to create file system for "dropbox:foo": is a file not a directory
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1466, in test_readtext
#     self.fs.makedir("foo")
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 168, in makedir
#     raise DirectoryExists(path)
# fs.errors.DirectoryExists: directory 'foo' exists
#
# ======================================================================
# ERROR: test_removedir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1082, in test_removedir
#     self.fs.makedirs("foo/bar/baz")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz' should be a directory
#
# ======================================================================
# ERROR: test_removetree (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1102, in test_removetree
#     self.fs.makedirs("foo/bar/baz")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar/baz' should be a directory
#
# ======================================================================
# ERROR: test_repeat_dir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 700, in test_repeat_dir
#     self.fs.makedirs("foo/foo/foo")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/foo/foo' should be a directory
#
# ======================================================================
# ERROR: test_tree (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1798, in test_tree
#     self.fs.makedirs("foo/bar")
#   File "/usr/lib/python3/dist-packages/fs/base.py", line 1068, in makedirs
#     dir_paths = tools.get_intermediate_dirs(self, path)
#   File "/usr/lib/python3/dist-packages/fs/tools.py", line 87, in get_intermediate_dirs
#     raise errors.DirectoryExpected(dir_path)
# fs.errors.DirectoryExpected: path 'foo/bar' should be a directory
#
# ======================================================================
# ERROR: test_upload (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1493, in test_upload
#     self.fs.upload("foo", bytes_file)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 229, in upload
#     local_path = str(file.name, encoding='utf-8')
# AttributeError: '_io.BytesIO' object has no attribute 'name'
#
# ======================================================================
# ERROR: test_upload_chunk_size (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1501, in test_upload_chunk_size
#     self.fs.upload("foo", bytes_file, chunk_size=8)
#   File "/home/raygan/Cosms/Dboy/Laydbug/dev/fs.rclonefs/src/fs/rclonefs/rclonefs.py", line 229, in upload
#     local_path = str(file.name, encoding='utf-8')
# AttributeError: '_io.BytesIO' object has no attribute 'name'
#
# ======================================================================
# FAIL: test_create (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1260, in test_create
#     self.assertFalse(self.fs.exists("foo"))
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_exists (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 515, in test_exists
#     self.assertTrue(self.fs.exists(""))
# AssertionError: False is not true
#
# ======================================================================
# FAIL: test_filterdir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1353, in test_filterdir
#     self.assertEqual(list(self.fs.filterdir("/", files=["*.py"])), [])
# AssertionError: Lists differ: [<dir 'Backup Large Vids iPh7'>, <dir 'Cam[138 chars]r1'>] != []
#
# First list contains 9 additional elements.
# First extra element 0:
# <dir 'Backup Large Vids iPh7'>
#
# + []
# - [<dir 'Backup Large Vids iPh7'>,
# -  <dir 'Camera Uploads'>,
# -  <dir 'Cosms'>,
# -  <dir 'INBOX'>,
# -  <dir 'Manual Photo Uploads'>,
# -  <dir 'More Chie Photos'>,
# -  <dir 'Sedona'>,
# -  <dir 'dir'>,
# -  <dir 'dir1'>]
#
# ======================================================================
# FAIL: test_invalid_chars (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 450, in test_invalid_chars
#     with self.assertRaises(errors.InvalidCharsInPath):
# AssertionError: InvalidCharsInPath not raised
#
# ======================================================================
# FAIL: test_isempty (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1445, in test_isempty
#     self.assertTrue(self.fs.isempty("/"))
# AssertionError: False is not true
#
# ======================================================================
# FAIL: test_isfile (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 379, in test_isfile
#     self.assertFalse(self.fs.isfile("foo.txt"))
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_islink (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 395, in test_islink
#     with self.assertRaises(errors.ResourceNotFound):
# AssertionError: ResourceNotFound not raised
#
# ======================================================================
# FAIL: test_listdir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 555, in test_listdir
#     self.assertEqual(self.fs.listdir("/"), [])
# AssertionError: Lists differ: ['Backup Large Vids iPh7', 'Camera Uploads[254 chars]and'] != []
#
# First list contains 24 additional elements.
# First extra element 0:
# 'Backup Large Vids iPh7'
#
# + []
# - ['Backup Large Vids iPh7',
# -  'Camera Uploads',
# -  'Cosms',
# -  'INBOX',
# -  'Manual Photo Uploads',
# -  'More Chie Photos',
# -  'Sedona',
# -  'bar',
# -  'dir',
# -  'dir1',
# -  'empty',
# -  'foo',
# -  'foo.txt',
# -  'foo1',
# -  'foo2',
# -  'hello.bin',
# -  'hello4.txt',
# -  'hello42.txt',
# -  'hello5.txt',
# -  'hello6.txt',
# -  'hello7.txt',
# -  'hello8.txt',
# -  'one',
# -  'onethousand']
#
# ======================================================================
# FAIL: test_makedir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 644, in test_makedir
#     with self.assertRaises(errors.DirectoryExists):
# AssertionError: DirectoryExists not raised
#
# ======================================================================
# FAIL: test_makedirs (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 677, in test_makedirs
#     self.assertFalse(self.fs.exists("foo"))
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_open_files (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 839, in test_open_files
#     self.assertFalse(f.readable())
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_openbin (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 940, in test_openbin
#     self.assertFalse(write_file.readable())
# AssertionError: True is not false
#
# ======================================================================
# FAIL: test_remove (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1062, in test_remove
#     with self.assertRaises(errors.ResourceNotFound):
# AssertionError: ResourceNotFound not raised
#
# ======================================================================
# FAIL: test_scandir (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1304, in test_scandir
#     self.assertEqual(list(iter_scandir), [])
# AssertionError: Lists differ: [<dir 'Backup Large Vids iPh7'>, <dir 'Cam[477 chars]xt'>] != []
#
# First list contains 28 additional elements.
# First extra element 0:
# <dir 'Backup Large Vids iPh7'>
#
# + []
# - [<dir 'Backup Large Vids iPh7'>,
# -  <dir 'Camera Uploads'>,
# -  <dir 'Cosms'>,
# -  <dir 'INBOX'>,
# -  <dir 'Manual Photo Uploads'>,
# -  <dir 'More Chie Photos'>,
# -  <dir 'Sedona'>,
# -  <dir 'baz'>,
# -  <dir 'dir'>,
# -  <dir 'dir1'>,
# -  <dir 'egg'>,
# -  <file 'empty'>,
# -  <file 'file.bin'>,
# -  <file 'foo'>,
# -  <file 'foo.txt'>,
# -  <file 'foo1'>,
# -  <file 'foo3'>,
# -  <file 'hello.bin'>,
# -  <file 'hello4.txt'>,
# -  <file 'hello42.txt'>,
# -  <file 'hello5.txt'>,
# -  <file 'hello6.txt'>,
# -  <file 'hello7.txt'>,
# -  <file 'hello8.txt'>,
# -  <file 'one'>,
# -  <file 'onethousand'>,
# -  <file 'text'>,
# -  <file 'top.txt'>]
#
# ======================================================================
# FAIL: test_setinfo (tests.TestMyFS)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/fs/test.py", line 1130, in test_setinfo
#     with self.assertRaises(errors.ResourceNotFound):
# AssertionError: ResourceNotFound not raised
#
# ----------------------------------------------------------------------
# Ran 78 tests in 758.524s
#
# FAILED (failures=15, errors=36, skipped=2)
